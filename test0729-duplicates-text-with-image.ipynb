# %%
import json, glob, os, numpy
from data_process_functions import *
from sklearn.ensemble import ExtraTreesClassifier 
os.chdir('/Users/adamyedidia/breast_cancer/spreadsheets/')
import openpyxl, pprint


SHEET_NAME = 'manisha_new.xlsx'
#LIST_OF_BINARY_COLS = ['Q', 'R', 'S', 'T','U','V','W','X','Y','Z','AA','AB','AC']
LIST_OF_BINARY_COLS = ['D','F','G','H','I','J','K','L','M','T','U','W','X','Y','AA','AE','AH','AJ']
LIST_OF_REAL_COLS = ['A','C','N','O','P','Q','R','S','V','Z','U','V','Z']  
ANSWER_COL = 'AQ'
        
with open('image-features-InceptionV3-CC.json') as data_file:
     image_features_map = json.load(data_file)
        
data,feature_names,result=dataprocessWithImage(SHEET_NAME,LIST_OF_BINARY_COLS,LIST_OF_REAL_COLS,ANSWER_COL,image_features_map)
yy=[1 if x=='M' else 0 for x in result]
print 'cancers numbers: %d' %yy.count(1)
y=np.array(yy)
print 'num data points:', len(yy)
X_structure=data[:,1:]
feature_names_structure=feature_names[1:]
n=X_structure.shape[0]
# Out:
# Real-valued Features:
# ID
# AGE
# WEIGHT
# HEIGHT
# BIRTH
# AGEPREG
# MAAGE
# MPAGE
# DENSITY
# PRIORBX
# ASSESS
# DENSITY
# PRIORBX
#
# Binary Features:
# RACE
# LOC
# SPROCS
# FBC
# PBC
# POC
# SMOKE
# ALCOHOL
# ASHKENAZI
# HORMONE
# ASSESS
# FIRSTMAM
# FROMSCREEN
# CLINFIND
# FINDTYPE
# SIDE
# BXTYPE
# BXPATH_CONCAT
#
# Result:
# SXRESULT
# data size is: 1118 X 156
# test reasult is: SXRESULT
# 1 207
# 1 793
# 1 887
# 1 928
# 1 1028
# 1 1366
# 1 1565
# 1 1611
# cancers numbers: 77
# num data points: 740

# %%
pass

# %%
pass

# %%
f_structure= ExtraTreesClassifier(n_estimators=200,max_depth=12,max_features=80,class_weight = {1:7},
                              random_state=123)
f_report = ExtraTreesClassifier(n_estimators=200,max_depth=10,max_features=500,class_weight = {1:5},
                              random_state=123)
'''
feature_ranking(f_structure,feature_names_structure,X_structure,y,'importantfeature_structure.txt',pp=1)
feature_ranking(f_report,feature_names_report_prune,ft_report_prune,y,'importantfeature_report.txt',pp=1)
'''
# Out:
# "\nfeature_ranking(f_structure,feature_names_structure,X_structure,y,'importantfeature_structure.txt',pp=1)\nfeature_ranking(f_report,feature_names_report_prune,ft_report_prune,y,'importantfeature_report.txt',pp=1)\n"

# %%
from sklearn.cross_validation import StratifiedShuffleSplit

n_str=100
n_report=180
weight =3
random_state= 127

#sss = StratifiedShuffleSplit(y, 10, test_size=0.05, random_state=1237)
#rs = cross_validation.ShuffleSplit(len(y), n_iter=10,test_size=.1, random_state=1237)

from sklearn.cross_validation import StratifiedKFold
skf = StratifiedKFold(y, 10, shuffle=True, random_state=random_state)

k=0

YTEST=[]
YTEST_index=[]
Probability=[]

for train_index, test_index in skf: 
        ff = ExtraTreesClassifier(n_estimators=200,max_depth=10,max_features=100
                                      ,class_weight = {1:weight},random_state=123)
        
        print 'new sets'
        X_train_struct, X_test_struct = X_structure[train_index], X_structure[test_index]
        #X_train_txt, X_test_txt = ft_report_prune[train_index], ft_report_prune[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        YTEST.append(y_test)
        YTEST_index.append(test_index)
   
        #k+=1
        #feature_ranking(f_structure,feature_names_structure,X_train_struct,y_train,'importantfeature_strcture_'+str(k)+'.txt',pp=0)
        #feature_ranking(f_report,feature_names_report_prune,X_train_txt,y_train,'importantfeature_report_'+str(k)+'.txt',pp=0)

        indx_structure=get_sorted_ft_idx(f_structure,X_train_struct,y_train,n=n_str)
        #indx_txt=get_sorted_ft_idx(f_report,X_train_txt,y_train,n=n_report)
        
        #X_train=np.concatenate((X_train_struct[:,indx_structure], X_train_txt[:,indx_txt]), axis=1)
        #X_test=np.concatenate((X_test_struct[:,indx_structure], X_test_txt[:,indx_txt]), axis=1)
        X_train = X_train_struct
        X_test = X_test_struct
        
       
        ff.fit(X_train, y_train)

        ff_proba=ff.predict_proba(X_test)
        Probability.append(ff_proba)
        indx1=np.where(y_test==1)
        indx2=np.where(y_test==0)
        yy= np.random.random_sample((len(y_test),))
        plt.clf()
        #plt.scatter([0, 1], [0, 1])
        plt.scatter(ff_proba[:,1][indx1], yy[indx1], c=y_test[indx1], s=50,marker='o')
        plt.scatter(ff_proba[:,1][indx2], yy[indx2], c=y_test[indx2], s=50,marker='+',label='no')
        plt.xlabel('probability')
        plt.ylabel('Random number')
        plt.legend(loc='best')
        plt.show()
        #prb=cus_probability(threshold, ff_proba[:,1])
        #prb=np.array(prb)
# Out:
# new sets
# new sets
# new sets
# new sets
# new sets
# new sets
# new sets
# new sets
# new sets
# new sets

# %%
p_all=[]
f_all=[]
r_all=[]
roc_all=[]
patients=[]
for ii in range(len(YTEST)):
    y_test=YTEST[ii]
    ff_proba=Probability[ii]
    roc=[]
    p=[]
    r=[]
    f=[]
    #results=[]
    pat=[]
    Thresh=[]
    for i in range(30):
        threshold=float(float(i+1)/80)
        Thresh.append(threshold)
        predicted=cus_predict(threshold, ff_proba[:,1])
        #results.append(predicted)

        fpr_rf, tpr_rf, _ = roc_curve(y_test,predicted)
        roc.append([fpr_rf, tpr_rf])
        p.append(precision_score(y_test,predicted))
        r.append(recall_score(y_test,predicted))
        f.append(f1_score(y_test,predicted))
        print(classification_report(y_test,predicted) )
        print 'roc_auc is %f :' %roc_auc_score(y_test,predicted)
        pt=len(predicted)-np.count_nonzero(predicted)
        print 'non cancer patient : %d' %pt
        pat.append(pt)

    #plt.scatter(prb[:,1],y_test)

    '''
    indxFb=np.intersect1d(np.where(ff_proba[:,1]>0.7 ),np.where(y_test==0))
    indxFm=np.intersect1d(np.where(ff_proba[:,1]<0.3),np.where(y_test==1))
    fp= X_test[indxFm][:,0]  ### The first column is the patient ID
    fn=X_test[indxFb][:,0]
    falsepositive.extend(fp)
    falsenegative.extend(fn)
    '''
    p_all.append(p)
    r_all.append(r)
    f_all.append(f)
    roc_all.append(roc)
    patients.append(pat)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.09      0.88      0.17         8
#
# avg / total       0.01      0.09      0.02        75
#
# roc_auc is 0.437500 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       0.50      0.01      0.03        67
#           1       0.10      0.88      0.17         8
#
# avg / total       0.46      0.11      0.04        75
#
# roc_auc is 0.444963 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       0.75      0.04      0.08        67
#           1       0.10      0.88      0.18         8
#
# avg / total       0.68      0.13      0.09        75
#
# roc_auc is 0.459888 :
# non cancer patient : 4
#              precision    recall  f1-score   support
#
#           0       0.83      0.07      0.14        67
#           1       0.10      0.88      0.18         8
#
# avg / total       0.76      0.16      0.14        75
#
# roc_auc is 0.474813 :
# non cancer patient : 6
#              precision    recall  f1-score   support
#
#           0       0.88      0.10      0.19        67
#           1       0.10      0.88      0.19         8
#
# avg / total       0.79      0.19      0.19        75
#
# roc_auc is 0.489739 :
# non cancer patient : 8
#              precision    recall  f1-score   support
#
#           0       0.91      0.15      0.26        67
#           1       0.11      0.88      0.19         8
#
# avg / total       0.82      0.23      0.25        75
#
# roc_auc is 0.512127 :
# non cancer patient : 11
#              precision    recall  f1-score   support
#
#           0       0.92      0.18      0.30        67
#           1       0.11      0.88      0.20         8
#
# avg / total       0.84      0.25      0.29        75
#
# roc_auc is 0.527052 :
# non cancer patient : 13
#              precision    recall  f1-score   support
#
#           0       0.91      0.30      0.45        67
#           1       0.11      0.75      0.20         8
#
# avg / total       0.82      0.35      0.42        75
#
# roc_auc is 0.524254 :
# non cancer patient : 22
#              precision    recall  f1-score   support
#
#           0       0.86      0.37      0.52        67
#           1       0.09      0.50      0.15         8
#
# avg / total       0.78      0.39      0.48        75
#
# roc_auc is 0.436567 :
# non cancer patient : 29
#              precision    recall  f1-score   support
#
#           0       0.89      0.48      0.62        67
#           1       0.10      0.50      0.17         8
#
# avg / total       0.81      0.48      0.57        75
#
# roc_auc is 0.488806 :
# non cancer patient : 36
#              precision    recall  f1-score   support
#
#           0       0.92      0.69      0.79        67
#           1       0.16      0.50      0.24         8
#
# avg / total       0.84      0.67      0.73        75
#
# roc_auc is 0.593284 :
# non cancer patient : 50
#              precision    recall  f1-score   support
#
#           0       0.91      0.79      0.85        67
#           1       0.18      0.38      0.24         8
#
# avg / total       0.84      0.75      0.78        75
#
# roc_auc is 0.583022 :
# non cancer patient : 58
#              precision    recall  f1-score   support
#
#           0       0.92      0.87      0.89        67
#           1       0.25      0.38      0.30         8
#
# avg / total       0.85      0.81      0.83        75
#
# roc_auc is 0.620336 :
# non cancer patient : 63
#              precision    recall  f1-score   support
#
#           0       0.92      0.91      0.92        67
#           1       0.33      0.38      0.35         8
#
# avg / total       0.86      0.85      0.86        75
#
# roc_auc is 0.642724 :
# non cancer patient : 66
#              precision    recall  f1-score   support
#
#           0       0.90      0.93      0.91        67
#           1       0.17      0.12      0.14         8
#
# avg / total       0.82      0.84      0.83        75
#
# roc_auc is 0.525187 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.90      0.94      0.92        67
#           1       0.20      0.12      0.15         8
#
# avg / total       0.83      0.85      0.84        75
#
# roc_auc is 0.532649 :
# non cancer patient : 70
#              precision    recall  f1-score   support
#
#           0       0.89      0.94      0.91        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.84      0.82        75
#
# roc_auc is 0.470149 :
# non cancer patient : 71
#              precision    recall  f1-score   support
#
#           0       0.89      0.96      0.92        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.85      0.82        75
#
# roc_auc is 0.477612 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.96      0.92        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.85      0.82        75
#
# roc_auc is 0.477612 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.96      0.92        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.85      0.82        75
#
# roc_auc is 0.477612 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.09        67
#           1       0.11      1.00      0.20         8
#
# avg / total       0.91      0.15      0.10        75
#
# roc_auc is 0.522388 :
# non cancer patient : 3
#              precision    recall  f1-score   support
#
#           0       1.00      0.07      0.14        67
#           1       0.11      1.00      0.21         8
#
# avg / total       0.91      0.17      0.15        75
#
# roc_auc is 0.537313 :
# non cancer patient : 5
#              precision    recall  f1-score   support
#
#           0       1.00      0.12      0.21        67
#           1       0.12      1.00      0.21         8
#
# avg / total       0.91      0.21      0.21        75
# /usr/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# roc_auc is 0.559701 :
# non cancer patient : 8
#              precision    recall  f1-score   support
#
#           0       1.00      0.18      0.30        67
#           1       0.13      1.00      0.23         8
#
# avg / total       0.91      0.27      0.30        75
#
# roc_auc is 0.589552 :
# non cancer patient : 12
#              precision    recall  f1-score   support
#
#           0       0.94      0.24      0.38        67
#           1       0.12      0.88      0.21         8
#
# avg / total       0.85      0.31      0.36        75
#
# roc_auc is 0.556903 :
# non cancer patient : 17
#              precision    recall  f1-score   support
#
#           0       0.96      0.33      0.49        67
#           1       0.13      0.88      0.23         8
#
# avg / total       0.87      0.39      0.46        75
#
# roc_auc is 0.601679 :
# non cancer patient : 23
#              precision    recall  f1-score   support
#
#           0       0.91      0.43      0.59        67
#           1       0.12      0.62      0.20         8
#
# avg / total       0.82      0.45      0.54        75
#
# roc_auc is 0.528918 :
# non cancer patient : 32
#              precision    recall  f1-score   support
#
#           0       0.93      0.57      0.70        67
#           1       0.15      0.62      0.24         8
#
# avg / total       0.84      0.57      0.65        75
#
# roc_auc is 0.596082 :
# non cancer patient : 41
#              precision    recall  f1-score   support
#
#           0       0.92      0.67      0.78        67
#           1       0.15      0.50      0.24         8
#
# avg / total       0.84      0.65      0.72        75
#
# roc_auc is 0.585821 :
# non cancer patient : 49
#              precision    recall  f1-score   support
#
#           0       0.89      0.73      0.80        67
#           1       0.10      0.25      0.14         8
#
# avg / total       0.81      0.68      0.73        75
#
# roc_auc is 0.490672 :
# non cancer patient : 55
#              precision    recall  f1-score   support
#
#           0       0.90      0.85      0.88        67
#           1       0.17      0.25      0.20         8
#
# avg / total       0.83      0.79      0.80        75
#
# roc_auc is 0.550373 :
# non cancer patient : 63
#              precision    recall  f1-score   support
#
#           0       0.90      0.91      0.90        67
#           1       0.14      0.12      0.13         8
#
# avg / total       0.82      0.83      0.82        75
#
# roc_auc is 0.517724 :
# non cancer patient : 68
#              precision    recall  f1-score   support
#
#           0       0.90      0.94      0.92        67
#           1       0.20      0.12      0.15         8
#
# avg / total       0.83      0.85      0.84        75
#
# roc_auc is 0.532649 :
# non cancer patient : 70
#              precision    recall  f1-score   support
#
#           0       0.89      0.96      0.92        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.85      0.82        75
#
# roc_auc is 0.477612 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.87      0.83        75
#
# roc_auc is 0.485075 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.99      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.88      0.84        75
#
# roc_auc is 0.492537 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.89      0.99      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.88      0.84        75
#
# roc_auc is 0.492537 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.89      0.99      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.88      0.84        75
#
# roc_auc is 0.492537 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        67
#           1       0.11      1.00      0.19         8
#
# avg / total       0.01      0.11      0.02        75
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       1.00      0.03      0.06        67
#           1       0.11      1.00      0.20         8
#
# avg / total       0.91      0.13      0.07        75
#
# roc_auc is 0.514925 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       1.00      0.03      0.06        67
#           1       0.11      1.00      0.20         8
#
# avg / total       0.91      0.13      0.07        75
#
# roc_auc is 0.514925 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       1.00      0.07      0.14        67
#           1       0.11      1.00      0.21         8
#
# avg / total       0.91      0.17      0.15        75
#
# roc_auc is 0.537313 :
# non cancer patient : 5
#              precision    recall  f1-score   support
#
#           0       1.00      0.07      0.14        67
#           1       0.11      1.00      0.21         8
#
# avg / total       0.91      0.17      0.15        75
#
# roc_auc is 0.537313 :
# non cancer patient : 5
#              precision    recall  f1-score   support
#
#           0       1.00      0.12      0.21        67
#           1       0.12      1.00      0.21         8
#
# avg / total       0.91      0.21      0.21        75
#
# roc_auc is 0.559701 :
# non cancer patient : 8
#              precision    recall  f1-score   support
#
#           0       0.91      0.15      0.26        67
#           1       0.11      0.88      0.19         8
#
# avg / total       0.82      0.23      0.25        75
#
# roc_auc is 0.512127 :
# non cancer patient : 11
#              precision    recall  f1-score   support
#
#           0       0.94      0.22      0.36        67
#           1       0.12      0.88      0.21         8
#
# avg / total       0.85      0.29      0.35        75
#
# roc_auc is 0.549440 :
# non cancer patient : 16
#              precision    recall  f1-score   support
#
#           0       0.96      0.39      0.55        67
#           1       0.15      0.88      0.25         8
#
# avg / total       0.88      0.44      0.52        75
#
# roc_auc is 0.631530 :
# non cancer patient : 27
#              precision    recall  f1-score   support
#
#           0       0.94      0.46      0.62        67
#           1       0.14      0.75      0.24         8
#
# avg / total       0.85      0.49      0.58        75
#
# roc_auc is 0.606343 :
# non cancer patient : 33
#              precision    recall  f1-score   support
#
#           0       0.95      0.54      0.69        67
#           1       0.16      0.75      0.27         8
#
# avg / total       0.86      0.56      0.64        75
#
# roc_auc is 0.643657 :
# non cancer patient : 38
#              precision    recall  f1-score   support
#
#           0       0.95      0.60      0.73        67
#           1       0.18      0.75      0.29         8
#
# avg / total       0.87      0.61      0.69        75
#
# roc_auc is 0.673507 :
# non cancer patient : 42
#              precision    recall  f1-score   support
#
#           0       0.90      0.66      0.76        67
#           1       0.12      0.38      0.18         8
#
# avg / total       0.81      0.63      0.70        75
#
# roc_auc is 0.515858 :
# non cancer patient : 49
#              precision    recall  f1-score   support
#
#           0       0.89      0.75      0.81        67
#           1       0.11      0.25      0.15         8
#
# avg / total       0.81      0.69      0.74        75
#
# roc_auc is 0.498134 :
# non cancer patient : 56
#              precision    recall  f1-score   support
#
#           0       0.89      0.88      0.89        67
#           1       0.11      0.12      0.12         8
#
# avg / total       0.81      0.80      0.81        75
#
# roc_auc is 0.502799 :
# non cancer patient : 66
#              precision    recall  f1-score   support
#
#           0       0.90      0.90      0.90        67
#           1       0.12      0.12      0.12         8
#
# avg / total       0.81      0.81      0.81        75
#
# roc_auc is 0.510261 :
# non cancer patient : 67
#              precision    recall  f1-score   support
#
#           0       0.90      0.90      0.90        67
#           1       0.12      0.12      0.12         8
#
# avg / total       0.81      0.81      0.81        75
#
# roc_auc is 0.510261 :
# non cancer patient : 67
#              precision    recall  f1-score   support
#
#           0       0.90      0.91      0.90        67
#           1       0.14      0.12      0.13         8
#
# avg / total       0.82      0.83      0.82        75
#
# roc_auc is 0.517724 :
# non cancer patient : 68
#              precision    recall  f1-score   support
#
#           0       0.90      0.94      0.92        67
#           1       0.20      0.12      0.15         8
#
# avg / total       0.83      0.85      0.84        75
#
# roc_auc is 0.532649 :
# non cancer patient : 70
#              precision    recall  f1-score   support
#
#           0       0.89      0.99      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.88      0.84        75
#
# roc_auc is 0.492537 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        67
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        75
#
# roc_auc is 0.500000 :
# non cancer patient : 75
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.01      0.11      0.02        74
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.01      0.11      0.02        74
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.01      0.11      0.02        74
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.12      0.05        74
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       1.00      0.03      0.06        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.14      0.07        74
#
# roc_auc is 0.515152 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       1.00      0.06      0.11        66
#           1       0.11      1.00      0.21         8
#
# avg / total       0.90      0.16      0.12        74
#
# roc_auc is 0.530303 :
# non cancer patient : 4
#              precision    recall  f1-score   support
#
#           0       1.00      0.08      0.14        66
#           1       0.12      1.00      0.21         8
#
# avg / total       0.90      0.18      0.15        74
#
# roc_auc is 0.537879 :
# non cancer patient : 5
#              precision    recall  f1-score   support
#
#           0       0.90      0.14      0.24        66
#           1       0.11      0.88      0.19         8
#
# avg / total       0.81      0.22      0.23        74
#
# roc_auc is 0.505682 :
# non cancer patient : 10
#              precision    recall  f1-score   support
#
#           0       0.82      0.21      0.34        66
#           1       0.09      0.62      0.15         8
#
# avg / total       0.74      0.26      0.32        74
#
# roc_auc is 0.418561 :
# non cancer patient : 17
#              precision    recall  f1-score   support
#
#           0       0.87      0.30      0.45        66
#           1       0.10      0.62      0.17         8
#
# avg / total       0.79      0.34      0.42        74
#
# roc_auc is 0.464015 :
# non cancer patient : 23
#              precision    recall  f1-score   support
#
#           0       0.88      0.42      0.57        66
#           1       0.10      0.50      0.16         8
#
# avg / total       0.79      0.43      0.53        74
#
# roc_auc is 0.462121 :
# non cancer patient : 32
#              precision    recall  f1-score   support
#
#           0       0.89      0.48      0.63        66
#           1       0.11      0.50      0.17         8
#
# avg / total       0.80      0.49      0.58        74
#
# roc_auc is 0.492424 :
# non cancer patient : 36
#              precision    recall  f1-score   support
#
#           0       0.90      0.58      0.70        66
#           1       0.12      0.50      0.20         8
#
# avg / total       0.82      0.57      0.65        74
#
# roc_auc is 0.537879 :
# non cancer patient : 42
#              precision    recall  f1-score   support
#
#           0       0.88      0.67      0.76        66
#           1       0.08      0.25      0.12         8
#
# avg / total       0.79      0.62      0.69        74
#
# roc_auc is 0.458333 :
# non cancer patient : 50
#              precision    recall  f1-score   support
#
#           0       0.89      0.73      0.80        66
#           1       0.10      0.25      0.14         8
#
# avg / total       0.80      0.68      0.73        74
#
# roc_auc is 0.488636 :
# non cancer patient : 54
#              precision    recall  f1-score   support
#
#           0       0.87      0.80      0.83        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.77      0.72      0.74        74
#
# roc_auc is 0.401515 :
# non cancer patient : 61
#              precision    recall  f1-score   support
#
#           0       0.88      0.86      0.87        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.78      0.77      0.78        74
#
# roc_auc is 0.431818 :
# non cancer patient : 65
#              precision    recall  f1-score   support
#
#           0       0.88      0.86      0.87        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.78      0.77      0.78        74
#
# roc_auc is 0.431818 :
# non cancer patient : 65
#              precision    recall  f1-score   support
#
#           0       0.88      0.89      0.89        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.80      0.79        74
#
# roc_auc is 0.446970 :
# non cancer patient : 67
#              precision    recall  f1-score   support
#
#           0       0.88      0.92      0.90        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.82      0.81        74
#
# roc_auc is 0.462121 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.88      0.92      0.90        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.82      0.81        74
#
# roc_auc is 0.462121 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.89      0.95      0.92        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.85      0.82        74
#
# roc_auc is 0.477273 :
# non cancer patient : 71
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.86      0.83        74
#
# roc_auc is 0.484848 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.86      0.83        74
#
# roc_auc is 0.484848 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        74
#
# roc_auc is 0.500000 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        74
#
# roc_auc is 0.500000 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.80      0.89      0.84        74
#
# roc_auc is 0.500000 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.01      0.11      0.02        74
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.12      0.05        74
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.12      0.05        74
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.12      0.05        74
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       1.00      0.03      0.06        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.14      0.07        74
#
# roc_auc is 0.515152 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       1.00      0.03      0.06        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.14      0.07        74
#
# roc_auc is 0.515152 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       1.00      0.05      0.09        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.15      0.10        74
#
# roc_auc is 0.522727 :
# non cancer patient : 3
#              precision    recall  f1-score   support
#
#           0       0.89      0.12      0.21        66
#           1       0.11      0.88      0.19         8
#
# avg / total       0.80      0.20      0.21        74
#
# roc_auc is 0.498106 :
# non cancer patient : 9
#              precision    recall  f1-score   support
#
#           0       0.89      0.24      0.38        66
#           1       0.11      0.75      0.19         8
#
# avg / total       0.80      0.30      0.36        74
#
# roc_auc is 0.496212 :
# non cancer patient : 18
#              precision    recall  f1-score   support
#
#           0       0.91      0.30      0.45        66
#           1       0.12      0.75      0.20         8
#
# avg / total       0.82      0.35      0.43        74
#
# roc_auc is 0.526515 :
# non cancer patient : 22
#              precision    recall  f1-score   support
#
#           0       0.93      0.38      0.54        66
#           1       0.13      0.75      0.22         8
#
# avg / total       0.84      0.42      0.50        74
#
# roc_auc is 0.564394 :
# non cancer patient : 27
#              precision    recall  f1-score   support
#
#           0       0.94      0.47      0.63        66
#           1       0.15      0.75      0.24         8
#
# avg / total       0.85      0.50      0.59        74
#
# roc_auc is 0.609848 :
# non cancer patient : 33
#              precision    recall  f1-score   support
#
#           0       0.95      0.53      0.68        66
#           1       0.16      0.75      0.27         8
#
# avg / total       0.86      0.55      0.63        74
#
# roc_auc is 0.640152 :
# non cancer patient : 37
#              precision    recall  f1-score   support
#
#           0       0.95      0.62      0.75        66
#           1       0.19      0.75      0.31         8
#
# avg / total       0.87      0.64      0.70        74
#
# roc_auc is 0.685606 :
# non cancer patient : 43
#              precision    recall  f1-score   support
#
#           0       0.96      0.74      0.84        66
#           1       0.26      0.75      0.39         8
#
# avg / total       0.89      0.74      0.79        74
#
# roc_auc is 0.746212 :
# non cancer patient : 51
#              precision    recall  f1-score   support
#
#           0       0.93      0.85      0.89        66
#           1       0.29      0.50      0.36         8
#
# avg / total       0.86      0.81      0.83        74
#
# roc_auc is 0.674242 :
# non cancer patient : 60
#              precision    recall  f1-score   support
#
#           0       0.94      0.89      0.91        66
#           1       0.36      0.50      0.42         8
#
# avg / total       0.87      0.85      0.86        74
#
# roc_auc is 0.696970 :
# non cancer patient : 63
#              precision    recall  f1-score   support
#
#           0       0.92      0.92      0.92        66
#           1       0.38      0.38      0.38         8
#
# avg / total       0.86      0.86      0.86        74
#
# roc_auc is 0.649621 :
# non cancer patient : 66
#              precision    recall  f1-score   support
#
#           0       0.93      0.94      0.93        66
#           1       0.43      0.38      0.40         8
#
# avg / total       0.87      0.88      0.87        74
#
# roc_auc is 0.657197 :
# non cancer patient : 67
#              precision    recall  f1-score   support
#
#           0       0.93      0.95      0.94        66
#           1       0.50      0.38      0.43         8
#
# avg / total       0.88      0.89      0.88        74
#
# roc_auc is 0.664773 :
# non cancer patient : 68
#              precision    recall  f1-score   support
#
#           0       0.93      0.97      0.95        66
#           1       0.60      0.38      0.46         8
#
# avg / total       0.89      0.91      0.90        74
#
# roc_auc is 0.672348 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.93      0.97      0.95        66
#           1       0.60      0.38      0.46         8
#
# avg / total       0.89      0.91      0.90        74
#
# roc_auc is 0.672348 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.91      0.97      0.94        66
#           1       0.50      0.25      0.33         8
#
# avg / total       0.87      0.89      0.88        74
#
# roc_auc is 0.609848 :
# non cancer patient : 70
#              precision    recall  f1-score   support
#
#           0       0.90      0.97      0.93        66
#           1       0.33      0.12      0.18         8
#
# avg / total       0.84      0.88      0.85        74
#
# roc_auc is 0.547348 :
# non cancer patient : 71
#              precision    recall  f1-score   support
#
#           0       0.90      0.97      0.93        66
#           1       0.33      0.12      0.18         8
#
# avg / total       0.84      0.88      0.85        74
#
# roc_auc is 0.547348 :
# non cancer patient : 71
#              precision    recall  f1-score   support
#
#           0       0.90      0.97      0.93        66
#           1       0.33      0.12      0.18         8
#
# avg / total       0.84      0.88      0.85        74
#
# roc_auc is 0.547348 :
# non cancer patient : 71
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.86      0.83        74
#
# roc_auc is 0.484848 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.86      0.83        74
#
# roc_auc is 0.484848 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.86      0.83        74
#
# roc_auc is 0.484848 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.86      0.83        74
#
# roc_auc is 0.484848 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.01      0.11      0.02        74
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.90      0.12      0.05        74
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       0.75      0.05      0.09        66
#           1       0.10      0.88      0.18         8
#
# avg / total       0.68      0.14      0.10        74
#
# roc_auc is 0.460227 :
# non cancer patient : 4
#              precision    recall  f1-score   support
#
#           0       0.75      0.05      0.09        66
#           1       0.10      0.88      0.18         8
#
# avg / total       0.68      0.14      0.10        74
#
# roc_auc is 0.460227 :
# non cancer patient : 4
#              precision    recall  f1-score   support
#
#           0       0.89      0.12      0.21        66
#           1       0.11      0.88      0.19         8
#
# avg / total       0.80      0.20      0.21        74
#
# roc_auc is 0.498106 :
# non cancer patient : 9
#              precision    recall  f1-score   support
#
#           0       0.83      0.15      0.26        66
#           1       0.10      0.75      0.17         8
#
# avg / total       0.75      0.22      0.25        74
#
# roc_auc is 0.450758 :
# non cancer patient : 12
#              precision    recall  f1-score   support
#
#           0       0.77      0.15      0.25        66
#           1       0.08      0.62      0.14         8
#
# avg / total       0.69      0.20      0.24        74
#
# roc_auc is 0.388258 :
# non cancer patient : 13
#              precision    recall  f1-score   support
#
#           0       0.73      0.17      0.27        66
#           1       0.07      0.50      0.12         8
#
# avg / total       0.66      0.20      0.26        74
#
# roc_auc is 0.333333 :
# non cancer patient : 15
#              precision    recall  f1-score   support
#
#           0       0.78      0.21      0.33        66
#           1       0.07      0.50      0.12         8
#
# avg / total       0.70      0.24      0.31        74
#
# roc_auc is 0.356061 :
# non cancer patient : 18
#              precision    recall  f1-score   support
#
#           0       0.78      0.21      0.33        66
#           1       0.07      0.50      0.12         8
#
# avg / total       0.70      0.24      0.31        74
#
# roc_auc is 0.356061 :
# non cancer patient : 18
#              precision    recall  f1-score   support
#
#           0       0.82      0.27      0.41        66
#           1       0.08      0.50      0.13         8
#
# avg / total       0.74      0.30      0.38        74
#
# roc_auc is 0.386364 :
# non cancer patient : 22
#              precision    recall  f1-score   support
#
#           0       0.89      0.47      0.61        66
#           1       0.10      0.50      0.17         8
#
# avg / total       0.80      0.47      0.57        74
#
# roc_auc is 0.484848 :
# non cancer patient : 35
#              precision    recall  f1-score   support
#
#           0       0.91      0.61      0.73        66
#           1       0.13      0.50      0.21         8
#
# avg / total       0.83      0.59      0.67        74
#
# roc_auc is 0.553030 :
# non cancer patient : 44
#              precision    recall  f1-score   support
#
#           0       0.91      0.65      0.76        66
#           1       0.15      0.50      0.23         8
#
# avg / total       0.83      0.64      0.70        74
#
# roc_auc is 0.575758 :
# non cancer patient : 47
#              precision    recall  f1-score   support
#
#           0       0.92      0.68      0.78        66
#           1       0.16      0.50      0.24         8
#
# avg / total       0.84      0.66      0.72        74
#
# roc_auc is 0.590909 :
# non cancer patient : 49
#              precision    recall  f1-score   support
#
#           0       0.91      0.74      0.82        66
#           1       0.15      0.38      0.21         8
#
# avg / total       0.83      0.70      0.75        74
#
# roc_auc is 0.558712 :
# non cancer patient : 54
#              precision    recall  f1-score   support
#
#           0       0.90      0.83      0.87        66
#           1       0.15      0.25      0.19         8
#
# avg / total       0.82      0.77      0.79        74
#
# roc_auc is 0.541667 :
# non cancer patient : 61
#              precision    recall  f1-score   support
#
#           0       0.90      0.85      0.88        66
#           1       0.17      0.25      0.20         8
#
# avg / total       0.82      0.78      0.80        74
#
# roc_auc is 0.549242 :
# non cancer patient : 62
#              precision    recall  f1-score   support
#
#           0       0.90      0.94      0.92        66
#           1       0.20      0.12      0.15         8
#
# avg / total       0.82      0.85      0.84        74
#
# roc_auc is 0.532197 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.90      0.94      0.92        66
#           1       0.20      0.12      0.15         8
#
# avg / total       0.82      0.85      0.84        74
#
# roc_auc is 0.532197 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.90      0.95      0.93        66
#           1       0.25      0.12      0.17         8
#
# avg / total       0.83      0.86      0.84        74
#
# roc_auc is 0.539773 :
# non cancer patient : 70
#              precision    recall  f1-score   support
#
#           0       0.90      0.98      0.94        66
#           1       0.50      0.12      0.20         8
#
# avg / total       0.86      0.89      0.86        74
#
# roc_auc is 0.554924 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94        66
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.88      0.83        74
#
# roc_auc is 0.492424 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.01      0.11      0.02        74
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.11      1.00      0.20         8
#
# avg / total       0.01      0.11      0.02        74
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
# ...
#
# avg / total       0.80      0.89      0.84        74
#
# roc_auc is 0.500000 :
# non cancer patient : 74
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.10      1.00      0.17         7
#
# avg / total       0.01      0.10      0.02        73
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.10      1.00      0.18         7
#
# avg / total       0.91      0.11      0.04        73
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       1.00      0.03      0.06        66
#           1       0.10      1.00      0.18         7
#
# avg / total       0.91      0.12      0.07        73
#
# roc_auc is 0.515152 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       0.60      0.05      0.08        66
#           1       0.07      0.71      0.13         7
#
# avg / total       0.55      0.11      0.09        73
#
# roc_auc is 0.379870 :
# non cancer patient : 5
#              precision    recall  f1-score   support
#
#           0       0.60      0.05      0.08        66
#           1       0.07      0.71      0.13         7
#
# avg / total       0.55      0.11      0.09        73
#
# roc_auc is 0.379870 :
# non cancer patient : 5
#              precision    recall  f1-score   support
#
#           0       0.71      0.08      0.14        66
#           1       0.08      0.71      0.14         7
#
# avg / total       0.65      0.14      0.14        73
#
# roc_auc is 0.395022 :
# non cancer patient : 7
#              precision    recall  f1-score   support
#
#           0       0.75      0.09      0.16        66
#           1       0.08      0.71      0.14         7
#
# avg / total       0.69      0.15      0.16        73
#
# roc_auc is 0.402597 :
# non cancer patient : 8
#              precision    recall  f1-score   support
#
#           0       0.85      0.17      0.28        66
#           1       0.08      0.71      0.15         7
#
# avg / total       0.77      0.22      0.27        73
#
# roc_auc is 0.440476 :
# non cancer patient : 13
#              precision    recall  f1-score   support
#
#           0       0.86      0.18      0.30        66
#           1       0.08      0.71      0.15         7
#
# avg / total       0.78      0.23      0.29        73
#
# roc_auc is 0.448052 :
# non cancer patient : 14
#              precision    recall  f1-score   support
#
#           0       0.89      0.24      0.38        66
#           1       0.09      0.71      0.16         7
#
# avg / total       0.81      0.29      0.36        73
#
# roc_auc is 0.478355 :
# non cancer patient : 18
#              precision    recall  f1-score   support
#
#           0       0.91      0.32      0.47        66
#           1       0.10      0.71      0.18         7
#
# avg / total       0.84      0.36      0.44        73
#
# roc_auc is 0.516234 :
# non cancer patient : 23
#              precision    recall  f1-score   support
#
#           0       0.93      0.41      0.57        66
#           1       0.11      0.71      0.20         7
#
# avg / total       0.85      0.44      0.53        73
#
# roc_auc is 0.561688 :
# non cancer patient : 29
#              precision    recall  f1-score   support
#
#           0       0.94      0.45      0.61        66
#           1       0.12      0.71      0.21         7
#
# avg / total       0.86      0.48      0.57        73
#
# roc_auc is 0.584416 :
# non cancer patient : 32
#              precision    recall  f1-score   support
#
#           0       0.95      0.56      0.70        66
#           1       0.15      0.71      0.24         7
#
# avg / total       0.87      0.58      0.66        73
#
# roc_auc is 0.637446 :
# non cancer patient : 39
#              precision    recall  f1-score   support
#
#           0       0.92      0.67      0.77        66
#           1       0.12      0.43      0.19         7
#
# avg / total       0.84      0.64      0.72        73
#
# roc_auc is 0.547619 :
# non cancer patient : 48
#              precision    recall  f1-score   support
#
#           0       0.93      0.76      0.83        66
#           1       0.16      0.43      0.23         7
#
# avg / total       0.85      0.73      0.78        73
#
# roc_auc is 0.593074 :
# non cancer patient : 54
#              precision    recall  f1-score   support
#
#           0       0.91      0.80      0.85        66
#           1       0.13      0.29      0.18         7
#
# avg / total       0.84      0.75      0.79        73
#
# roc_auc is 0.544372 :
# non cancer patient : 58
#              precision    recall  f1-score   support
#
#           0       0.92      0.88      0.90        66
#           1       0.20      0.29      0.24         7
#
# avg / total       0.85      0.82      0.84        73
#
# roc_auc is 0.582251 :
# non cancer patient : 63
#              precision    recall  f1-score   support
#
#           0       0.92      0.89      0.91        66
#           1       0.22      0.29      0.25         7
#
# avg / total       0.85      0.84      0.84        73
#
# roc_auc is 0.589827 :
# non cancer patient : 64
#              precision    recall  f1-score   support
#
#           0       0.92      0.92      0.92        66
#           1       0.29      0.29      0.29         7
#
# avg / total       0.86      0.86      0.86        73
#
# roc_auc is 0.604978 :
# non cancer patient : 66
#              precision    recall  f1-score   support
#
#           0       0.92      0.92      0.92        66
#           1       0.29      0.29      0.29         7
#
# avg / total       0.86      0.86      0.86        73
#
# roc_auc is 0.604978 :
# non cancer patient : 66
#              precision    recall  f1-score   support
#
#           0       0.91      0.92      0.92        66
#           1       0.17      0.14      0.15         7
#
# avg / total       0.84      0.85      0.84        73
#
# roc_auc is 0.533550 :
# non cancer patient : 67
#              precision    recall  f1-score   support
#
#           0       0.92      0.98      0.95        66
#           1       0.50      0.14      0.22         7
#
# avg / total       0.88      0.90      0.88        73
#
# roc_auc is 0.563853 :
# non cancer patient : 71
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.10      1.00      0.17         7
#
# avg / total       0.01      0.10      0.02        73
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.10      1.00      0.17         7
#
# avg / total       0.01      0.10      0.02        73
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        66
#           1       0.10      1.00      0.17         7
#
# avg / total       0.01      0.10      0.02        73
#
# roc_auc is 0.500000 :
# non cancer patient : 0
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.10      1.00      0.18         7
#
# avg / total       0.91      0.11      0.04        73
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.03        66
#           1       0.10      1.00      0.18         7
#
# avg / total       0.91      0.11      0.04        73
#
# roc_auc is 0.507576 :
# non cancer patient : 1
#              precision    recall  f1-score   support
#
#           0       1.00      0.03      0.06        66
#           1       0.10      1.00      0.18         7
#
# avg / total       0.91      0.12      0.07        73
#
# roc_auc is 0.515152 :
# non cancer patient : 2
#              precision    recall  f1-score   support
#
#           0       1.00      0.09      0.17        66
#           1       0.10      1.00      0.19         7
#
# avg / total       0.91      0.18      0.17        73
#
# roc_auc is 0.545455 :
# non cancer patient : 6
#              precision    recall  f1-score   support
#
#           0       1.00      0.14      0.24        66
#           1       0.11      1.00      0.20         7
#
# avg / total       0.91      0.22      0.24        73
#
# roc_auc is 0.568182 :
# non cancer patient : 9
#              precision    recall  f1-score   support
#
#           0       1.00      0.15      0.26        66
#           1       0.11      1.00      0.20         7
#
# avg / total       0.91      0.23      0.26        73
#
# roc_auc is 0.575758 :
# non cancer patient : 10
#              precision    recall  f1-score   support
#
#           0       1.00      0.26      0.41        66
#           1       0.12      1.00      0.22         7
#
# avg / total       0.92      0.33      0.39        73
#
# roc_auc is 0.628788 :
# non cancer patient : 17
#              precision    recall  f1-score   support
#
#           0       0.95      0.27      0.42        66
#           1       0.11      0.86      0.20         7
#
# avg / total       0.87      0.33      0.40        73
#
# roc_auc is 0.564935 :
# non cancer patient : 19
#              precision    recall  f1-score   support
#
#           0       0.92      0.36      0.52        66
#           1       0.11      0.71      0.19         7
#
# avg / total       0.84      0.40      0.49        73
#
# roc_auc is 0.538961 :
# non cancer patient : 26
#              precision    recall  f1-score   support
#
#           0       0.84      0.39      0.54        66
#           1       0.05      0.29      0.08         7
#
# avg / total       0.76      0.38      0.49        73
#
# roc_auc is 0.339827 :
# non cancer patient : 31
#              precision    recall  f1-score   support
#
#           0       0.84      0.55      0.66        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.76      0.49      0.60        73
#
# roc_auc is 0.272727 :
# non cancer patient : 43
#              precision    recall  f1-score   support
#
#           0       0.86      0.65      0.74        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.78      0.59      0.67        73
#
# roc_auc is 0.325758 :
# non cancer patient : 50
#              precision    recall  f1-score   support
#
#           0       0.87      0.71      0.78        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.79      0.64      0.71        73
#
# roc_auc is 0.356061 :
# non cancer patient : 54
#              precision    recall  f1-score   support
#
#           0       0.88      0.76      0.81        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.79      0.68      0.74        73
#
# roc_auc is 0.378788 :
# non cancer patient : 57
#              precision    recall  f1-score   support
#
#           0       0.89      0.86      0.88        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.81      0.78      0.79        73
#
# roc_auc is 0.431818 :
# non cancer patient : 64
#              precision    recall  f1-score   support
#
#           0       0.89      0.89      0.89        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.81      0.81      0.81        73
#
# roc_auc is 0.446970 :
# non cancer patient : 66
#              precision    recall  f1-score   support
#
#           0       0.90      0.94      0.92        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.81      0.85      0.83        73
#
# roc_auc is 0.469697 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.90      0.94      0.92        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.81      0.85      0.83        73
#
# roc_auc is 0.469697 :
# non cancer patient : 69
#              precision    recall  f1-score   support
#
#           0       0.90      0.98      0.94        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.89      0.85        73
#
# roc_auc is 0.492424 :
# non cancer patient : 72
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95        66
#           1       0.00      0.00      0.00         7
#
# avg / total       0.82      0.90      0.86        73
#
# roc_auc is 0.500000 :
# non cancer patient : 73
# /usr/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
n=2
#m=f_all.shape[1]
m=10

f_all=np.array(f_all)
r_all=np.array(r_all)
patients=np.array(patients)
print 'trainging size: %d' %f_all[:-n,i].shape
for i in range(m):
    print average(f_all[:-n,i])
print "  \n test result"
for i in range(m):
    print average(f_all[-n:,i])
print " \n train result"
for i in range(m):
    print average(r_all[:-n,i])
print "  \ntest result"

for i in range(m):
    print average(r_all[-n:,i])

print "\n train result"
t=sum([len(l) for l in YTEST_index[:-n] ])
for i in range(m):
    print float(sum(patients[:-n,i])/float(sum([len(l) for l in YTEST_index[:-n] ])))

print ' \n test result'
for i in range(m):
    print float(sum(patients[-n:,i])/float(sum([len(l) for l in YTEST_index[-n:] ])))
    
patients[9,3]

# %%
#[54486, 86819,111803]
TestID=54486
newdata=[]
newtxt=[]
ID=[]
newy=[]
for i in range(data.shape[0]):
    if data[i,0] ==TestID:
        ID.append(data[i,0])
        newdata.append(data[i,1:])
        newtxt.append(ft_report_p[i,:])
        newy.append(y[i])
    '''
    else:
        if yy[i]==1:
            ID.append(data[i,0])
            newdata.append(data[i])
            newtxt.append(ft_report_p[i,:])
            newy.append(yy[i])
    '''
newdata=np.array(newdata)
newtxt=np.array(newtxt)
newy=np.array(newy)

# %%
X_test_special=np.concatenate((newdata[:,indx_structure], newtxt[:,indx_txt]), axis=1)
ff_proba=ff.predict_proba(X_test_special)
Probability.append(ff_proba)
indx1=np.where(newy==1)
indx2=np.where(newy==0)
yy= np.random.random_sample((len(newy),))
plt.clf()
#plt.scatter([0, 1], [0, 1])
plt.scatter(ff_proba[:,1][indx1], yy[indx1], c=newy[indx1], s=50,marker='o',label='cancer')
plt.scatter(ff_proba[:,1][indx2], yy[indx2], c=newy[indx2], s=50,marker='+',label='no cancer')
plt.xlabel('probability')
plt.ylabel('Random number')
plt.legend(loc='best')
plt.show()
#prb=cus_probability(threshold, ff_proba[:,1])
#prb=np.array(prb)

# %%
print str(X_test.shape)
print len( indx_structure)
print len( indx_txt)
